# %% [markdown]
# <span style="color:red;font-weight:700;font-size:40px">
#     Assignment 4 - DNNs with PyTorch
# </span>

# %% [markdown]
# ### Aerospace Computing
# For bugs/comments reach out to me ~ kalagodk@mail.uc.edu

# %%
from assignment import Assignment

# %% [markdown]
# # Question 1

# %%
# Call the model. Fill in the rest
model1 = Assignment()

# %%
# Plot the data set. One line of code
model1.data_set.plot()

# %%
# Block to input parameters. Five lines of code
model1.epochs = 2
model1.learning_rate = 0.16
model1.layers = [1, 22, 12, 12, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train(save_at = 100)

# %%
# Check validation error. One line of code 
model1.validation()
# Out:
# Validation error for the trained model = 0.9034427934142428

# %%
# Run validation against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 0.9034427934142428
# Validation error against real data: 0.26686947646979675

# %% [markdown]
# # Question 2

# %% [markdown]
# # Effect of Neural Network depth

# %%
# Use one hidden layer. Keep the rest same as Question 1. Five lines of code
model1.epochs = 2
model1.learning_rate = 0.17
model1.layers = [1, 22, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train(save_at = 100)

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 406020968601444.0
# Validation error against real data: 406020968601444.0

# %% [markdown]
# # Effect of number of neurons

# %%
# Use one hidden layer. Increase the number of neurons to four times from question 1
# Keep the rest same as Question 1. Five lines of code
model1.epochs = 2
model1.learning_rate = 0.07
model1.layers = [1, 88, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.epochs = 201
model1.continue_train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 2579399.1119537354
# Validation error against real data: 2579135.233894363

# %% [markdown]
# # Solution 2c

# %% [markdown]
# # Train-test split effect

# %%
# Increase train set to 90%. Keep the rest same as Question 1. Five lines of code
model1.epochs = 2
model1.learning_rate = 0.16
model1.layers = [1, 22, 12, 12, 1]
model1.momentum = 0
model1.p_train = 0.9

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train(save_at = 100)

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 2.6482815134115754
# Validation error against real data: 1.9327896689633803

# %% [markdown]
# # Effect of epochs

# %%
# Set epochs to 10. Keep the rest same as Question 1. Five lines of code
model1.epochs = 10
model1.learning_rate = 0.16
model1.layers = [1, 22, 12, 12, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train(save_at = 100)

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 1.1729813202293826
# Validation error against real data: 0.10776153741321881

# %%
# Set epochs to 2000. Keep the rest same as Question 1. Five lines of code
model1.epochs = 2000
model1.learning_rate = 0.16
model1.layers = [1, 22, 12, 12, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train(save_at = 100)

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 0.8755565746281526
# Validation error against real data: 0.04619388555124915

# %% [markdown]
# # Effect of learning rate

# %%
# Set learning rate to 0.1. Keep the rest same as Question 1. Five lines of code
model1.epochs = 2
model1.learning_rate = 0.1
model1.layers = [1, 22, 12, 12, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train(save_at = 100)

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 0.9199272489795476
# Validation error against real data: 0.17271902648748583

# %%
# Set learning rate to 0.001. Keep the rest same as Question 1. Five lines of code
model1.epochs = 2
model1.learning_rate = 0.001
model1.layers = [1, 22, 12, 12, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train(save_at = 100)

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 14.332868189094427
# Validation error against real data: 14.714078119107455

# %% [markdown]
# ### Fill in the following table. Replace "x" with numerics. Specify Underfit or Overfit in comparison to against Original Solution unless until specified otherwise

# %% [markdown]
# - Note: Double-click to edit

# %% [markdown]
# | Parameter            | Test Loss   | Validation Error |                                  Comment       |
# | :---                 |    :----:   |      :----:      |                                           ---: |
# | Original Sol.        |     3.145    |       0.903       |                                   Best Solution|
# | Layers - Low         |     4.06e14    |       1.5e12       |                                Overfit|
# | Neurons - High       |     2.648    |       2.645       |                                Underfit|
# | Train-Test           |     1.172    |       1.58       |                                Underfit|
# | Epochs - Low         |     0.875    |       0.992       |                                Underfit|
# | Epochs - High        |     0.919    |       2.49       |                                Underfit|
# | Learning Rate - Low  |     14.33    |       16.424       |                                Overfit|

# %% [markdown]
# ## Please add further comments below

# %% [markdown]
# a.) While reducing the number of layers can help mitigate overfitting in some cases, it's essential to strike a balance between model complexity and simplicity. It's crucial to experiment and find the optimal number of layers for the given problem
#
# b.) Similar to reducing the number of layers, decreasing the number of neurons should be done cautiously, balancing model complexity with the problem's complexity
#
# c.) Increasing the training data percentage is generally a good practice, especially if the dataset is small. However, it's essential to ensure a balanced distribution between training, validation, and test sets.
#
# d.) Finding the right number of epochs is crucial. This is often done using techniques like early stopping or monitoring the validation error
#
# e.) Adjusting the learning rate is crucial for optimizing the training process. Too high a learning rate might cause the model to diverge or oscillate, while too low a learning rate might result in slow convergence. It's often necessary to tune the learning rate based on the specific problem and model architecture.
